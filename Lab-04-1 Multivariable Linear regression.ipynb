# %%
import numpy as np
import torch
import torch.optim as optim

# %%
x_train = torch.FloatTensor([[73, 80, 75],
                             [93, 88, 93],
                             [89, 91, 90],
                             [96, 98, 100],
                             [73, 66, 70]])
y_train = torch.FloatTensor([[152], [185], [180], [196], [142]])

# %%
w = torch.zeros((3,1), requires_grad = True)
b = torch.zeros(1, requires_grad = True)

# %%
optimizer = optim.SGD([w,b], lr = 1e-5)

# %%
epochs = 30

for epoch in range(1, epochs+1):
    # 다중이면 벡터, 행렬의 곱을 이용
    hypothesis = x_train.matmul(w) + b
    cost = torch.mean((hypothesis - y_train)**2)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Hypothesis: {}, Cost: {:.6f}'.format(epoch,epochs,hypothesis.squeeze().detach(),cost.item()))
# Out:
# Epoch    1/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch    2/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch    3/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch    4/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch    5/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch    6/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch    7/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch    8/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch    9/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   10/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   11/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   12/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   13/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   14/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   15/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   16/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   17/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   18/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   19/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   20/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   21/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   22/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   23/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   24/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   25/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   26/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   27/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   28/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   29/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan
# Epoch   30/30 Hypothesis: tensor([nan, nan, nan, nan, nan]), Cost: nan

# %%
w = torch.zeros((3,1), requires_grad = True)
b = torch.zeros(1, requires_grad = True)

# %%
import torch.nn as nn
import torch.nn.functional as F

class MultivariateLinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3,1)

    def forward(self,x):
        return self.linear(x)


model = MultivariateLinearRegressionModel()
optimizer = optim.SGD([w,b], lr=1e-5)

# %%
epochs = 20
for epoch in range(1, epochs+1):
    hypothesis = model(x_train)

    cost  = F.mse_loss(hypothesis, y_train)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

# %%
print(w)
# Out:
# tensor([[0.],
#         [0.],
#         [0.]], requires_grad=True)
