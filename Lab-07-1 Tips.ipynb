# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# For reproducibility
torch.manual_seed(1)

# %%
x_train = torch.FloatTensor([[1, 2, 1],
                             [1, 3, 2],
                             [1, 3, 4],
                             [1, 5, 5],
                             [1, 7, 5],
                             [1, 2, 5],
                             [1, 6, 6],
                             [1, 7, 7]
                            ])
y_train = torch.LongTensor([2, 2, 2, 1, 1, 1, 0, 0])

x_test = torch.FloatTensor([[2, 1, 1], [3, 1, 2], [3, 3, 4]])
y_test = torch.LongTensor([2, 2, 2])

# %%
class SoftmaxClassification(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3,3)

    def forward(self, x):
        return self.linear(x)

# %%
model = SoftmaxClassification()

# %%
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
def train(model, optimizer, x_train, y_train):
    epochs = 100
    for epoch in range(epochs):
        prediction = model(x_train)
        cost = F.cross_entropy(prediction, y_train)

        optimizer.zero_grad()
        cost.backward()
        optimizer.step()

        print('Epoch: {:4d}, Cost: {:.6f}'.format(epoch, cost.item()))

# %%
train(model, optimizer, x_train, y_train)
# Out:
# Epoch:    0, Cost: 4.381592
# Epoch:    1, Cost: 1.734146
# Epoch:    2, Cost: 1.080521
# Epoch:    3, Cost: 0.905182
# Epoch:    4, Cost: 0.898634
# Epoch:    5, Cost: 0.892782
# Epoch:    6, Cost: 0.887332
# Epoch:    7, Cost: 0.882152
# Epoch:    8, Cost: 0.877222
# Epoch:    9, Cost: 0.872484
# Epoch:   10, Cost: 0.867925
# Epoch:   11, Cost: 0.863514
# Epoch:   12, Cost: 0.859241
# Epoch:   13, Cost: 0.855090
# Epoch:   14, Cost: 0.851053
# Epoch:   15, Cost: 0.847119
# Epoch:   16, Cost: 0.843283
# Epoch:   17, Cost: 0.839537
# Epoch:   18, Cost: 0.835878
# Epoch:   19, Cost: 0.832300
# Epoch:   20, Cost: 0.828799
# Epoch:   21, Cost: 0.825372
# Epoch:   22, Cost: 0.822016
# Epoch:   23, Cost: 0.818727
# Epoch:   24, Cost: 0.815503
# Epoch:   25, Cost: 0.812341
# Epoch:   26, Cost: 0.809240
# Epoch:   27, Cost: 0.806196
# Epoch:   28, Cost: 0.803208
# Epoch:   29, Cost: 0.800274
# Epoch:   30, Cost: 0.797393
# Epoch:   31, Cost: 0.794561
# Epoch:   32, Cost: 0.791779
# Epoch:   33, Cost: 0.789043
# Epoch:   34, Cost: 0.786354
# Epoch:   35, Cost: 0.783708
# Epoch:   36, Cost: 0.781106
# Epoch:   37, Cost: 0.778546
# Epoch:   38, Cost: 0.776026
# Epoch:   39, Cost: 0.773545
# Epoch:   40, Cost: 0.771103
# Epoch:   41, Cost: 0.768698
# Epoch:   42, Cost: 0.766329
# Epoch:   43, Cost: 0.763996
# Epoch:   44, Cost: 0.761696
# Epoch:   45, Cost: 0.759430
# Epoch:   46, Cost: 0.757197
# Epoch:   47, Cost: 0.754995
# Epoch:   48, Cost: 0.752824
# Epoch:   49, Cost: 0.750682
# Epoch:   50, Cost: 0.748571
# Epoch:   51, Cost: 0.746487
# Epoch:   52, Cost: 0.744432
# Epoch:   53, Cost: 0.742404
# Epoch:   54, Cost: 0.740403
# Epoch:   55, Cost: 0.738427
# Epoch:   56, Cost: 0.736477
# Epoch:   57, Cost: 0.734552
# Epoch:   58, Cost: 0.732650
# Epoch:   59, Cost: 0.730773
# Epoch:   60, Cost: 0.728918
# Epoch:   61, Cost: 0.727086
# Epoch:   62, Cost: 0.725277
# Epoch:   63, Cost: 0.723489
# Epoch:   64, Cost: 0.721722
# Epoch:   65, Cost: 0.719976
# Epoch:   66, Cost: 0.718250
# Epoch:   67, Cost: 0.716544
# Epoch:   68, Cost: 0.714858
# Epoch:   69, Cost: 0.713190
# Epoch:   70, Cost: 0.711541
# Epoch:   71, Cost: 0.709911
# Epoch:   72, Cost: 0.708299
# Epoch:   73, Cost: 0.706704
# Epoch:   74, Cost: 0.705126
# Epoch:   75, Cost: 0.703565
# Epoch:   76, Cost: 0.702021
# Epoch:   77, Cost: 0.700494
# Epoch:   78, Cost: 0.698982
# Epoch:   79, Cost: 0.697486
# Epoch:   80, Cost: 0.696005
# Epoch:   81, Cost: 0.694539
# Epoch:   82, Cost: 0.693088
# Epoch:   83, Cost: 0.691652
# Epoch:   84, Cost: 0.690230
# Epoch:   85, Cost: 0.688822
# Epoch:   86, Cost: 0.687427
# Epoch:   87, Cost: 0.686047
# Epoch:   88, Cost: 0.684680
# Epoch:   89, Cost: 0.683325
# Epoch:   90, Cost: 0.681984
# Epoch:   91, Cost: 0.680655
# Epoch:   92, Cost: 0.679338
# Epoch:   93, Cost: 0.678034
# Epoch:   94, Cost: 0.676742
# Epoch:   95, Cost: 0.675461
# Epoch:   96, Cost: 0.674193
# Epoch:   97, Cost: 0.672935
# Epoch:   98, Cost: 0.671689
# Epoch:   99, Cost: 0.670454

# %%
def test(model, optimizer, x_test, y_test):
    prediction = model(x_test)
    predicted_classes = prediction.max(1)[1] # 인덱스 나옴
    correct_count = (predicted_classes == y_test).sum().item()
    cost = F.cross_entropy(prediction, y_test)

    print('Accuracy: {}%, Cost: {:.6f}'.format(correct_count / len(y_test) * 100, cost.item()))

# %%
test(model, optimizer, x_test, y_test)
# Out:
# Accuracy: 100.0%, Cost: 0.075352
